# %% [raw]
# To see if we can make exclude gates.

# %%
import galaxy_tests
import ResolvedStellarPops as rsp
import ResolvedStellarPops.PadovaTracks as pc
import os
import numpy as np

# %%
reload(pc)
# Out:
# <module 'ResolvedStellarPops.PadovaTracks' from '/home/rosenfield/research/python/ResolvedStellarPops/PadovaTracks.pyc'>

# %%
pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
tracks_base = '/home/rosenfield/research/stel_evo/CAF09_S12D_NS/'
prefixs = ['S12D_NS_Z0.0001_Y0.249',
           'S12D_NS_Z0.0002_Y0.249',
           'S12D_NS_Z0.0005_Y0.249',
           'S12D_NS_Z0.001_Y0.25',
           'S12D_NS_Z0.002_Y0.252',
           'S12D_NS_Z0.004_Y0.256',
           'S12D_NS_Z0.006_Y0.259',
           'S12D_NS_Z0.008_Y0.263',
           'S12D_NS_Z0.014_Y0.273',
           'S12D_NS_Z0.017_Y0.279',
           'S12D_NS_Z0.01_Y0.267',
           'S12D_NS_Z0.02_Y0.284',
           'S12D_NS_Z0.03_Y0.302',
           'S12D_NS_Z0.04_Y0.321',
           'S12D_NS_Z0.05_Y0.339',
           'S12D_NS_Z0.06_Y0.356']

# only need to do this once.
#[pc.quick_color_em(tracks_base, prefix, photsys='wfc3snap') for prefix in prefixs]

# %%
input_file = '/home/rosenfield/research/stel_evo/parsec2match/parsec2match.inp'
infile = pc.default_params(rsp.fileIO.load_input(input_file))
infile['masses'] = [12]
infile['track_search_term'] = '*snap'
del infile['prefixs']
infile['do_interpolation'] = False
track_sets = [pc.TracksForMatch(prefix=p, **infile) for p in prefixs]
# Out:
# Some errors were detected !
#     Line #583 (got 363 columns instead of 83)
#     Line #585 (got 853 columns instead of 83)
#     Line #586 (got 223 columns instead of 83)
#     Line #587 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #622 (got 1203 columns instead of 83)
#     Line #623 (got 223 columns instead of 83)
#     Line #624 (got 153 columns instead of 83)
#     Line #625 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #622 (got 223 columns instead of 83)
#     Line #623 (got 363 columns instead of 83)
#     Line #624 (got 503 columns instead of 83)
#     Line #625 (got 433 columns instead of 83)
#     Line #626 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #576 (got 573 columns instead of 83)
#     Line #577 (got 713 columns instead of 83)
#     Line #578 (got 293 columns instead of 83)
#     Line #579 (got 153 columns instead of 83)
#     Line #580 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #573 (got 1203 columns instead of 83)
#     Line #574 (got 293 columns instead of 83)
#     Line #575 (got 223 columns instead of 83)
# Some errors were detected !
#     Line #571 (got 1133 columns instead of 83)
#     Line #572 (got 503 columns instead of 83)
#     Line #575 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #575 (got 1133 columns instead of 83)
#     Line #576 (got 433 columns instead of 83)
#     Line #577 (got 153 columns instead of 83)
#     Line #578 (got 153 columns instead of 83)
#     Line #2761 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #578 (got 1203 columns instead of 83)
#     Line #579 (got 363 columns instead of 83)
#     Line #580 (got 223 columns instead of 83)
#     Line #582 (got 153 columns instead of 83)
#     Line #781 (got 153 columns instead of 83)
#     Line #783 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #585 (got 363 columns instead of 83)
#     Line #586 (got 993 columns instead of 83)
#     Line #587 (got 223 columns instead of 83)
#     Line #588 (got 153 columns instead of 83)
#     Line #2153 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #2176 (got 153 columns instead of 83)
#     Line #2585 (got 153 columns instead of 83)
#     Line #2590 (got 223 columns instead of 83)
#     Line #2751 (got 153 columns instead of 83)
#     Line #2762 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #581 (got 1273 columns instead of 83)
#     Line #582 (got 293 columns instead of 83)
#     Line #583 (got 153 columns instead of 83)
#     Line #584 (got 153 columns instead of 83)
#     Line #773 (got 223 columns instead of 83)
#     Line #774 (got 153 columns instead of 83)
#     Line #2161 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #2709 (got 153 columns instead of 83)
#     Line #2735 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #586 (got 643 columns instead of 83)
#     Line #587 (got 713 columns instead of 83)
#     Line #588 (got 433 columns instead of 83)
#     Line #589 (got 153 columns instead of 83)
#     Line #591 (got 153 columns instead of 83)
#     Line #2538 (got 153 columns instead of 83)
#     Line #2573 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #583 (got 573 columns instead of 83)
#     Line #584 (got 853 columns instead of 83)
#     Line #585 (got 363 columns instead of 83)
#     Line #586 (got 153 columns instead of 83)
#     Line #2669 (got 153 columns instead of 83)
#     Line #2776 (got 153 columns instead of 83)
#     Line #2866 (got 153 columns instead of 83)
#     Line #2878 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #584 (got 1483 columns instead of 83)
#     Line #585 (got 223 columns instead of 83)
#     Line #586 (got 153 columns instead of 83)
#     Line #2551 (got 153 columns instead of 83)
#     Line #2785 (got 153 columns instead of 83)
#     Line #2891 (got 153 columns instead of 83)
#     Line #3020 (got 153 columns instead of 83)
#     Line #3036 (got 153 columns instead of 83)
#     Line #3049 (got 153 columns instead of 83)
#     Line #3117 (got 153 columns instead of 83)
#     Line #3179 (got 153 columns instead of 83)
#     Line #3184 (got 153 columns instead of 83)
#     Line #3190 (got 153 columns instead of 83)
#     Line #3195 (got 153 columns instead of 83)
#     Line #3196 (got 153 columns instead of 83)
#     Line #3209 (got 153 columns instead of 83)
#     Line #3213 (got 153 columns instead of 83)
#     Line #3216 (got 153 columns instead of 83)
#     Line #3221 (got 153 columns instead of 83)
#     Line #3224 (got 223 columns instead of 83)
#     Line #3233 (got 153 columns instead of 83)
#     Line #3238 (got 153 columns instead of 83)
#     Line #3244 (got 153 columns instead of 83)
#     Line #3245 (got 153 columns instead of 83)
#     Line #3246 (got 153 columns instead of 83)
#     Line #3250 (got 153 columns instead of 83)
#     Line #3255 (got 153 columns instead of 83)
#     Line #3258 (got 223 columns instead of 83)
#     Line #3259 (got 153 columns instead of 83)
#     Line #3261 (got 153 columns instead of 83)
#     Line #3268 (got 153 columns instead of 83)
#     Line #3269 (got 153 columns instead of 83)
#     Line #3271 (got 153 columns instead of 83)
#     Line #3272 (got 223 columns instead of 83)
#     Line #3276 (got 223 columns instead of 83)
#     Line #3281 (got 153 columns instead of 83)
#     Line #3283 (got 153 columns instead of 83)
#     Line #3289 (got 153 columns instead of 83)
#     Line #3290 (got 153 columns instead of 83)
#     Line #3293 (got 153 columns instead of 83)
#     Line #3297 (got 153 columns instead of 83)
#     Line #3304 (got 153 columns instead of 83)
#     Line #3307 (got 433 columns instead of 83)
#     Line #3309 (got 153 columns instead of 83)
#     Line #3310 (got 153 columns instead of 83)
#     Line #3313 (got 223 columns instead of 83)
#     Line #3319 (got 153 columns instead of 83)
#     Line #3329 (got 153 columns instead of 83)
#     Line #3338 (got 153 columns instead of 83)
#     Line #3343 (got 153 columns instead of 83)
#     Line #3346 (got 153 columns instead of 83)
#     Line #3350 (got 153 columns instead of 83)
#     Line #3355 (got 153 columns instead of 83)
#     Line #3358 (got 223 columns instead of 83)
#     Line #3360 (got 153 columns instead of 83)
#     Line #3361 (got 153 columns instead of 83)
#     Line #3368 (got 153 columns instead of 83)
#     Line #3369 (got 153 columns instead of 83)
#     Line #3372 (got 153 columns instead of 83)
#     Line #3391 (got 153 columns instead of 83)
#     Line #3392 (got 153 columns instead of 83)
#     Line #3394 (got 153 columns instead of 83)
#     Line #3424 (got 153 columns instead of 83)
#     Line #3429 (got 153 columns instead of 83)
#     Line #3780 (got 153 columns instead of 83)
#     Line #3855 (got 153 columns instead of 83)
#     Line #3920 (got 153 columns instead of 83)
# Some errors were detected !
#     Line #582 (got 1483 columns instead of 83)
#     Line #583 (got 293 columns instead of 83)
#     Line #584 (got 153 columns instead of 83)
#     Line #774 (got 153 columns instead of 83)
#     Line #2627 (got 153 columns instead of 83)
#     Line #2632 (got 153 columns instead of 83)
#     Line #2647 (got 153 columns instead of 83)
#     Line #2662 (got 153 columns instead of 83)
#     Line #2663 (got 223 columns instead of 83)
#     Line #2665 (got 153 columns instead of 83)
#     Line #2666 (got 153 columns instead of 83)
#     Line #2669 (got 153 columns instead of 83)
#     Line #2752 (got 153 columns instead of 83)
#     Line #2773 (got 153 columns instead of 83)
#     Line #2776 (got 153 columns instead of 83)
#     Line #2777 (got 153 columns instead of 83)
#     Line #2779 (got 153 columns instead of 83)
#     Line #2801 (got 153 columns instead of 83)
#     Line #2856 (got 153 columns instead of 83)
#     Line #3001 (got 153 columns instead of 83)
#     Line #3081 (got 153 columns instead of 83)
#     Line #3349 (got 153 columns instead of 83)
#     Line #3377 (got 153 columns instead of 83)
#     Line #3385 (got 153 columns instead of 83)
#     Line #3397 (got 153 columns instead of 83)
#     Line #3414 (got 153 columns instead of 83)
#     Line #3451 (got 153 columns instead of 83)
#     Line #3872 (got 153 columns instead of 83)
#     Line #3940 (got 153 columns instead of 83)
#     Line #3959 (got 153 columns instead of 83)
#     Line #3965 (got 153 columns instead of 83)
#     Line #3966 (got 153 columns instead of 83)
#     Line #3968 (got 153 columns instead of 83)
#     Line #3977 (got 153 columns instead of 83)
#     Line #3989 (got 153 columns instead of 83)
#     Line #3997 (got 153 columns instead of 83)
#     Line #4005 (got 153 columns instead of 83)
#     Line #4008 (got 223 columns instead of 83)
#     Line #4014 (got 153 columns instead of 83)
#     Line #4018 (got 223 columns instead of 83)
#     Line #4020 (got 153 columns instead of 83)
#     Line #4029 (got 153 columns instead of 83)
#     Line #4030 (got 153 columns instead of 83)
#     Line #4040 (got 153 columns instead of 83)
#     Line #4043 (got 153 columns instead of 83)
#     Line #4047 (got 153 columns instead of 83)
#     Line #4055 (got 153 columns instead of 83)
#     Line #4063 (got 153 columns instead of 83)
#     Line #4066 (got 223 columns instead of 83)
#     Line #4067 (got 223 columns instead of 83)
#     Line #4071 (got 153 columns instead of 83)
#     Line #4076 (got 153 columns instead of 83)
#     Line #4091 (got 153 columns instead of 83)
#     Line #4101 (got 153 columns instead of 83)
#     Line #4103 (got 223 columns instead of 83)
#     Line #4118 (got 153 columns instead of 83)
#     Line #4121 (got 153 columns instead of 83)
#     Line #4126 (got 153 columns instead of 83)
#     Line #4141 (got 153 columns instead of 83)
#     Line #4150 (got 153 columns instead of 83)
#     Line #4156 (got 153 columns instead of 83)
#     Line #4158 (got 223 columns instead of 83)
#     Line #4170 (got 153 columns instead of 83)
#     Line #4172 (got 153 columns instead of 83)
#     Line #4175 (got 153 columns instead of 83)
#     Line #4177 (got 153 columns instead of 83)
#     Line #4181 (got 223 columns instead of 83)
#     Line #4187 (got 153 columns instead of 83)
#     Line #4194 (got 153 columns instead of 83)
#     Line #4195 (got 153 columns instead of 83)
#     Line #4200 (got 153 columns instead of 83)
#     Line #4201 (got 153 columns instead of 83)
#     Line #4207 (got 153 columns instead of 83)
#     Line #4208 (got 153 columns instead of 83)
#     Line #4214 (got 153 columns instead of 83)
#     Line #4227 (got 223 columns instead of 83)
#     Line #4232 (got 153 columns instead of 83)
#     Line #4239 (got 153 columns instead of 83)
#     Line #4240 (got 153 columns instead of 83)
#     Line #4241 (got 223 columns instead of 83)
#     Line #4242 (got 223 columns instead of 83)
#     Line #4247 (got 153 columns instead of 83)
#     Line #4248 (got 223 columns instead of 83)
#     Line #4249 (got 153 columns instead of 83)
#     Line #4262 (got 153 columns instead of 83)
#     Line #4268 (got 153 columns instead of 83)
#     Line #4290 (got 223 columns instead of 83)
#     Line #4298 (got 153 columns instead of 83)
#     Line #4300 (got 153 columns instead of 83)
#     Line #4301 (got 153 columns instead of 83)
#     Line #4311 (got 153 columns instead of 83)
#     Line #4313 (got 153 columns instead of 83)
#     Line #4318 (got 153 columns instead of 83)
#     Line #4319 (got 153 columns instead of 83)
#     Line #4320 (got 153 columns instead of 83)
#     Line #4321 (got 153 columns instead of 83)
#     Line #4330 (got 153 columns instead of 83)
#     Line #4331 (got 153 columns instead of 83)
#     Line #4334 (got 153 columns instead of 83)
#     Line #4337 (got 153 columns instead of 83)
#     Line #4340 (got 153 columns instead of 83)
#     Line #4342 (got 223 columns instead of 83)
#     Line #4346 (got 293 columns instead of 83)
#     Line #4348 (got 153 columns instead of 83)
#     Line #4359 (got 153 columns instead of 83)
#     Line #4360 (got 293 columns instead of 83)
#     Line #4363 (got 153 columns instead of 83)
#     Line #4365 (got 293 columns instead of 83)
#     Line #4366 (got 153 columns instead of 83)
#     Line #4367 (got 153 columns instead of 83)
#     Line #4370 (got 153 columns instead of 83)
#     Line #4372 (got 153 columns instead of 83)
#     Line #4375 (got 223 columns instead of 83)
#     Line #4376 (got 153 columns instead of 83)
#     Line #4378 (got 153 columns instead of 83)
#     Line #4379 (got 223 columns instead of 83)
#     Line #4380 (got 223 columns instead of 83)
#     Line #4383 (got 153 columns instead of 83)
#     Line #4385 (got 153 columns instead of 83)
#     Line #4390 (got 153 columns instead of 83)
#     Line #4393 (got 223 columns instead of 83)
#     Line #4395 (got 153 columns instead of 83)
#     Line #4402 (got 293 columns instead of 83)
#     Line #4403 (got 153 columns instead of 83)
#     Line #4406 (got 223 columns instead of 83)
#     Line #4409 (got 153 columns instead of 83)
#     Line #4412 (got 223 columns instead of 83)
#     Line #4421 (got 153 columns instead of 83)
#     Line #4425 (got 153 columns instead of 83)
#     Line #4431 (got 223 columns instead of 83)
#     Line #4435 (got 153 columns instead of 83)
#     Line #4443 (got 153 columns instead of 83)
#     Line #4451 (got 153 columns instead of 83)
#     Line #4456 (got 223 columns instead of 83)
#     Line #4457 (got 223 columns instead of 83)
#     Line #4458 (got 223 columns instead of 83)
#     Line #4460 (got 153 columns instead of 83)
#     Line #4462 (got 153 columns instead of 83)
#     Line #4464 (got 153 columns instead of 83)
#     Line #4467 (got 223 columns instead of 83)
#     Line #4470 (got 153 columns instead of 83)
#     Line #4475 (got 153 columns instead of 83)
#     Line #4481 (got 153 columns instead of 83)
#     Line #4488 (got 223 columns instead of 83)
#     Line #4489 (got 153 columns instead of 83)
#     Line #4490 (got 153 columns instead of 83)
#     Line #4491 (got 153 columns instead of 83)
#     Line #4494 (got 223 columns instead of 83)
#     Line #4498 (got 153 columns instead of 83)
#     Line #4506 (got 153 columns instead of 83)
#     Line #4507 (got 153 columns instead of 83)
#     Line #4510 (got 153 columns instead of 83)
#     Line #4515 (got 153 columns instead of 83)
#     Line #4518 (got 363 columns instead of 83)
#     Line #4520 (got 153 columns instead of 83)
#     Line #4526 (got 153 columns instead of 83)
#     Line #4527 (got 223 columns instead of 83)
#     Line #4534 (got 223 columns instead of 83)
#     Line #4537 (got 153 columns instead of 83)
#     Line #4540 (got 223 columns instead of 83)
#     Line #4551 (got 153 columns instead of 83)
#     Line #4552 (got 223 columns instead of 83)
#     Line #4556 (got 153 columns instead of 83)
#     Line #4557 (got 153 columns instead of 83)
#     Line #4559 (got 223 columns instead of 83)
#     Line #4560 (got 153 columns instead of 83)
#     Line #4563 (got 293 columns instead of 83)
#     Line #4576 (got 153 columns instead of 83)
#     Line #4579 (got 153 columns instead of 83)
#     Line #4580 (got 433 columns instead of 83)
#     Line #4581 (got 293 columns instead of 83)
#     Line #4592 (got 223 columns instead of 83)
#     Line #4593 (got 223 columns instead of 83)
#     Line #4594 (got 153 columns instead of 83)
#     Line #4595 (got 293 columns instead of 83)
#     Line #4597 (got 223 columns instead of 83)
#     Line #4598 (got 153 columns instead of 83)
#     Line #4599 (got 223 columns instead of 83)
#     Line #4613 (got 153 columns instead of 83)
#     Line #4619 (got 363 columns instead of 83)
#     Line #4620 (got 293 columns instead of 83)
#     Line #4621 (got 153 columns instead of 83)
#     Line #4622 (got 223 columns instead of 83)
#     Line #4623 (got 293 columns instead of 83)
#     Line #4624 (got 153 columns instead of 83)
#     Line #4629 (got 153 columns instead of 83)
#     Line #4634 (got 153 columns instead of 83)
#     Line #4637 (got 153 columns instead of 83)
#     Line #4648 (got 223 columns instead of 83)
#     Line #4651 (got 293 columns instead of 83)
#     Line #4658 (got 223 columns instead of 83)
#     Line #4666 (got 153 columns instead of 83)
#     Line #4671 (got 153 columns instead of 83)
#     Line #4673 (got 153 columns instead of 83)
#     Line #4681 (got 293 columns instead of 83)
#     Line #4682 (got 153 columns instead of 83)
#     Line #4683 (got 293 columns instead of 83)
#     Line #4690 (got 153 columns instead of 83)
#     Line #4698 (got 363 columns instead of 83)
#     Line #4703 (got 293 columns instead of 83)
#     Line #4704 (got 223 columns instead of 83)
#     Line #4705 (got 153 columns instead of 83)
#     Line #4710 (got 223 columns instead of 83)
#     Line #4713 (got 223 columns instead of 83)
#     Line #4714 (got 293 columns instead of 83)
#     Line #4718 (got 223 columns instead of 83)
#     Line #4720 (got 223 columns instead of 83)
#     Line #4721 (got 503 columns instead of 83)
#     Line #4722 (got 223 columns instead of 83)
#     Line #4725 (got 293 columns instead of 83)
#     Line #4726 (got 223 columns instead of 83)
#     Line #4727 (got 223 columns instead of 83)
#     Line #4731 (got 153 columns instead of 83)
#     Line #4742 (got 153 columns instead of 83)
#     Line #4745 (got 153 columns instead of 83)
#     Line #4746 (got 153 columns instead of 83)
#     Line #4747 (got 293 columns instead of 83)
#     Line #4748 (got 363 columns instead of 83)
#     Line #4749 (got 363 columns instead of 83)
#     Line #4750 (got 363 columns instead of 83)
#     Line #4752 (got 153 columns instead of 83)
#     Line #4753 (got 223 columns instead of 83)
#     Line #4754 (got 153 columns instead of 83)
#     Line #4755 (got 153 columns instead of 83)
#     Line #4757 (got 503 columns instead of 83)
#     Line #4762 (got 153 columns instead of 83)
#     Line #4767 (got 503 columns instead of 83)
#     Line #4769 (got 223 columns instead of 83)
#     Line #4774 (got 293 columns instead of 83)
#     Line #4777 (got 153 columns instead of 83)
#     Line #4781 (got 153 columns instead of 83)
#     Line #4783 (got 363 columns instead of 83)
#     Line #4784 (got 153 columns instead of 83)
#     Line #4789 (got 223 columns instead of 83)
#     Line #4792 (got 153 columns instead of 83)
#     Line #4795 (got 153 columns instead of 83)
#     Line #4796 (got 223 columns instead of 83)
#     Line #4800 (got 153 columns instead of 83)
#     Line #4805 (got 223 columns instead of 83)
#     Line #4807 (got 223 columns instead of 83)
#     Line #4811 (got 153 columns instead of 83)
#     Line #4816 (got 153 columns instead of 83)
#     Line #4817 (got 153 columns instead of 83)
#     Line #4818 (got 293 columns instead of 83)
#     Line #4823 (got 153 columns instead of 83)
#     Line #4825 (got 293 columns instead of 83)
#     Line #4826 (got 153 columns instead of 83)
#     Line #4830 (got 153 columns instead of 83)
#     Line #4831 (got 153 columns instead of 83)
#     Line #4835 (got 153 columns instead of 83)
#     Line #4837 (got 153 columns instead of 83)
#     Line #4839 (got 153 columns instead of 83)
#     Line #4840 (got 503 columns instead of 83)
#     Line #4841 (got 503 columns instead of 83)
#     Line #4844 (got 223 columns instead of 83)
#     Line #4846 (got 223 columns instead of 83)
#     Line #4855 (got 153 columns instead of 83)
#     Line #4856 (got 153 columns instead of 83)
#     Line #4860 (got 153 columns instead of 83)
#     Line #4861 (got 293 columns instead of 83)
#     Line #4865 (got 153 columns instead of 83)
#     Line #4868 (got 153 columns instead of 83)
#     Line #4876 (got 223 columns instead of 83)
#     Line #4880 (got 153 columns instead of 83)
#     Line #4882 (got 153 columns instead of 83)
#     Line #4883 (got 153 columns instead of 83)
#     Line #4887 (got 363 columns instead of 83)
#     Line #4891 (got 223 columns instead of 83)
#     Line #4893 (got 153 columns instead of 83)
#     Line #4895 (got 153 columns instead of 83)
#     Line #4900 (got 223 columns instead of 83)
#     Line #4904 (got 153 columns instead of 83)
#     Line #4905 (got 433 columns instead of 83)
#     Line #4908 (got 153 columns instead of 83)
#     Line #4917 (got 153 columns instead of 83)
#     Line #4924 (got 223 columns instead of 83)
#     Line #4928 (got 223 columns instead of 83)
#     Line #4932 (got 223 columns instead of 83)
#     Line #4934 (got 153 columns instead of 83)
#     Line #4936 (got 153 columns instead of 83)
#     Line #4938 (got 153 columns instead of 83)
#     Line #4943 (got 223 columns instead of 83)
#     Line #4947 (got 153 columns instead of 83)
#     Line #4952 (got 293 columns instead of 83)
#     Line #4956 (got 153 columns instead of 83)
#     Line #4957 (got 153 columns instead of 83)
#     Line #4960 (got 153 columns instead of 83)
#     Line #4962 (got 223 columns instead of 83)
#     Line #4964 (got 153 columns instead of 83)
#     Line #4967 (got 153 columns instead of 83)
#     Line #4977 (got 153 columns instead of 83)
#     Line #4979 (got 153 columns instead of 83)
#     Line #4980 (got 433 columns instead of 83)
#     Line #4982 (got 293 columns instead of 83)
#     Line #4983 (got 153 columns instead of 83)
#     Line #4985 (got 153 columns instead of 83)
#     Line #4993 (got 153 columns instead of 83)
#     Line #4996 (got 153 columns instead of 83)
#     Line #4997 (got 153 columns instead of 83)
#     Line #4999 (got 643 columns instead of 83)
#     Line #5007 (got 293 columns instead of 83)
#     Line #5016 (got 293 columns instead of 83)
#     Line #5020 (got 153 columns instead of 83)
#     Line #5026 (got 293 columns instead of 83)
#     Line #5027 (got 223 columns instead of 83)
#     Line #5030 (got 153 columns instead of 83)
#     Line #5031 (got 643 columns instead of 83)
#     Line #5035 (got 153 columns instead of 83)

# %%
zs = np.array([track_sets[i].tracks[0].Z for i in range(len(track_sets))])

# %%
tracks = [t.tracks[0] for t in track_sets]

# %%
_ = [t.ptcri.load_sandro_eeps(t) for t in tracks]

# %%
# I wrote this thinking I should only cut color, mag brighter than the weighted average
# metallicity in the last 20 Myr. If I did that, it would simply bias match to use lower 
# metallicities to fit the upper MS. Instead, the entire region should be cut,
# which means use the lowest metallicity track to cut the stars.
def match_metallicities():
    met_dict = {}
    sfh_dir = '/home/rosenfield/research/TP-AGBcalib/SNAP/data/sfh/'
    sfh_files = rsp.fileIO.get_files(sfh_dir, '*dat')
    for i in range(len(sfh_files)):
        target = sfh_files[i].split('_')[2]
        age, sfr, z = np.genfromtxt(sfh_files[i], unpack=True)
        age = np.array(age)[1::8]
        sfr = np.array(sfr)[1::8]
        z = np.array(z)[1::8]
        young, = np.nonzero(age <= 7.3)
        met_dict[target] = np.average(z[young], weights=sfr[young]
    #met_dict['M81-DEEP'] = 0.03
    #met_dict['ESO540-030'] = 
    return met_dict
met_dict = match_metallicities()
# Out:
#   File "<ipython-input-238-923a04cccde8>", line 13
#     met_dict['M81-DEEP'] = 0.03
#            ^
# SyntaxError: invalid syntax

# %%
fits_src='/home/rosenfield/research/TP-AGBcalib/SNAP/data/angst_no_trim'

# %%
met_dict
# Out:
# {'DDO71': '0.0027',
#  'DDO78': '0.0019',
#  'DDO82': '0.0042',
#  'HS117': '0.0023',
#  'IC2574-SGS': '0.0018',
#  'KDG73': '0.0007',
#  'KKH37': '0.0014',
#  'M81-DEEP': 0.01,
#  'NGC0300-WIDE1': '0.0088',
#  'NGC0404-DEEP': '0.0074',
#  'NGC2403-DEEP': '0.0044',
#  'NGC2403-HALO-6': '0.0045',
#  'NGC2976-DEEP': '0.0029',
#  'NGC3077-PHOENIX': '0.0158',
#  'NGC3741': '0.0007',
#  'NGC404': '0.0074',
#  'NGC4163': '0.0018',
#  'NGC7793-HALO-6': '0.0036',
#  'SCL-DE1': '0.0014',
#  'UGC-04459': '0.0022',
#  'UGC-4305-1': '0.0011',
#  'UGC-4305-2': '0.0011',
#  'UGC-5139': '0.0032',
#  'UGC8508': '0.0011',
#  'UGCA292': '0.0003'}

# %%
fits_files = rsp.fileIO.get_files(fits_src, '*fits')

# %%
gal_kw = {'hla': True, 'photsys': 'wfc3snap', 'band': 'opt', 'angst': True,
          'filetype': 'fitstable'}

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig, (axs) = rsp.graphics.GraphicsUtils.setup_multiplot(len(fits_files), figsize=(30,30))
axs = np.squeeze(np.concatenate(axs))

for i, fits_file in enumerate(fits_files):
    gal = rsp.Galaxies.galaxy(fits_file, **gal_kw)
    tget = gal.target.upper()
    if 'SN' in tget:
        tget = 'NGC2403-DEEP'
    if '300' in tget:
        tget = 'NGC0300-WIDE1'
    if 'UGC4305-1' in tget:
        tget = 'UGC-4305-1'
    if 'UGC4305-2' in tget:
        tget = 'UGC-4305-2'
    if 'NGC404-DEEP' in tget:
        tget = 'NGC0404-DEEP'
    if '4459' in tget:
        tget = 'UGC-04459'
    if '5139' in tget:
        tget = 'UGC-5139'
    try:
        z = float(met_dict[tget])
        zclose = np.argmin(abs(z-zs))
        #print z, zs[zclose]
        track = tracks[-1]
    except KeyError:
        print 'WHOOPS', tget
    gal.plot_cmd(gal.color, gal.mag2, levels=3, threshold=100, ax=axs[i])
    gal.photsys = 'wfc3snap'
    gal.decorate_cmd(ax=axs[i])
    for track in tracks:

        ims = track.ptcri.sptcri[4]
        Mag1 = track.data[gal.filter1][ims:]
        Mag2 = track.data[gal.filter2][ims:]

        mag1 = rsp.astronomy_utils.Mag2mag(Mag1, gal.filter1, 'wfc3snap',
                                       filter1=gal.filter1, filter2=gal.filter2,
                                       target=gal.target)
        mag2 = rsp.astronomy_utils.Mag2mag(Mag2, gal.filter2, 'wfc3snap', 
                                       filter1=gal.filter1, filter2=gal.filter2,
                                       target=gal.target)
        color = mag1 - mag2
        track_set.plot_track(track, '', '', xdata=color, ydata=mag2, clean=False, ax=axs[i],
                         plt_kw={'lw':3, 'color':'k'})
        track_set.plot_track(track, '', '', xdata=color, ydata=mag2, clean=False, ax=axs[i],
                         plt_kw={'lw':2, 'color':'yellow'})
# Out:
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# M81_DEEP using M81-DEEP
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# NGC3077_PHOENIX using NGC3077-PHOENIX
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# SN_NGC2403_PR using NGC2403-DEEP
# WHOOPS
#  ESO540-030

# %%
plt.close('all')

# %%
track.ptcri.sptcri[4]
# Out:
# 1182
